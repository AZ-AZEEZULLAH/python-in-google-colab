# %% [markdown]
# <a href="https://colab.research.google.com/github/AZ-AZEEZULLAH/python-in-google-colab/blob/main/Assignment_Hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q langchain_google_genai
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.0 MB/s eta 0:00:00

# %%
import langchain_google_genai as genai

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import  ConversationChain,LLMChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate
from langchain.tools import tool
import json

# %%
api_key ="AIzaSyCB2iSXx8Mr5G0RBFhb6dk85w4EJ8dklwQ"

# %%
llm = ChatGoogleGenerativeAI(
    api_key = api_key,
    model = "gemini-2.0-flash-exp",
    temperature =0.7,
    max_output_tokens = 100,
)

# %%
response=llm.invoke("Who is the founder of Google?")
print(response)
# Out:
# content='Google was founded by **Larry Page** and **Sergey Brin**.\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-279c0151-b7e1-4f74-9cf3-e718620eb0df-0' usage_metadata={'input_tokens': 8, 'output_tokens': 14, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}}

# %%
response=llm.invoke("What is the capital of USA?")
print("Single prompt",response)
# Out:
# Single prompt content='The capital of the USA is **Washington, D.C.**\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-1827109f-1e66-4632-8c5f-5177121a7be6-0' usage_metadata={'input_tokens': 8, 'output_tokens': 14, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}}

# %%
response=llm.invoke(["Who is the founder of Google?","What is the capital of USA?"])
print("Multiple prompt",response)
# Out:
# Multiple prompt content='The capital of the USA is **Washington, D.C.**\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-f1882968-d3ac-494d-b79b-1ab23db3a4b6-0' usage_metadata={'input_tokens': 16, 'output_tokens': 14, 'total_tokens': 30, 'input_token_details': {'cache_read': 0}}

# %%
response=llm.invoke("Write five line note about AI")
print("\nNote prompt response", response)
# Out:
# Note prompt response content='AI is rapidly evolving, transforming our world.\nIt powers everything from search engines to medical diagnoses.\nEthical considerations and responsible development are crucial.\nThe potential benefits are vast, but so are the risks.\nUnderstanding and adapting to AI is essential for the future.\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-b0511394-e47f-4a84-9f78-ed886534b135-0' usage_metadata={'input_tokens': 7, 'output_tokens': 55, 'total_tokens': 62, 'input_token_details': {'ca
# ...

# %%
memory =ConversationBufferMemory()
conversation = ConversationChain(
    llm=llm,
    memory=memory,
)

# %%
print("\nConversation#1",conversation.predict(input="Hello,World in Lanchain"))
# Out:
# Conversation#1 Okay, you'd like to see "Hello, World!" implemented using Langchain. That's a great way to start exploring the framework! Langchain is a powerful tool for building applications that leverage large language models (LLMs), but it can sometimes feel a bit abstract. Let's break down a simple "Hello, World!" example to understand some of its core concepts.
#
# Since Langchain is primarily about connecting to LLMs and orchestrating workflows, a basic "Hello, World

# %%
print("\nConversation 1",conversation.run("Who is the founder of Turkey"))
print("\nConversation 2",conversation.run("When was  He born & Death?"))
print("\nConversation 3",conversation.run("Tell me more about his"))
# Out:
# Conversation 1 You're asking again about the founder of Turkey. As I've mentioned several times now, the founder of the Republic of Turkey is **Mustafa Kemal Atatürk**.
#
# I understand you might be trying to confirm the information or perhaps exploring different ways to ask the same question. It's perfectly fine to repeat questions, but I want to assure you that the answer remains consistent: Mustafa Kemal Atatürk is the founder of Turkey.
#
# Perhaps we could explore a different aspect of his life, his
#
# Conversation 2 Okay, you're asking again for the birth and death dates of Mustafa Kemal Atatürk. I understand you want to be sure of the information.
#
# *   **Birth:** While the exact date is debated, it is widely accepted that he was born in **1881**. The official date recognized in Turkey is **May 19, 1881**, although this was symbolically chosen and not necessarily his actual birth date.
# *   **Death:** Mustafa Kemal Atatürk **died
#
# ...

# %%
def get_weather(location):
  return f"The weather in {location} is sunny and warm"
  weather_tool = Tool(
    name="WeatherTool",
    func=get_weather,
    description="Provide the current weather for a given location"
)
  weather_response = weather_tool.run("Karachi")
  print("\nWeather Tool Response",weather_response)

# %%
custom_response=llm.invoke("What is the weather in Karachi?")
print("\nCustom Response",custom_response)
# Out:
# Custom Response content='Okay, to give you the most accurate weather information for Karachi, I need to know when you\'re asking about. Weather is constantly changing! \n\n**To help me give you the best answer, please tell me:**\n\n* **Are you asking about the weather right now?** (I can give you a general idea based on current data)\n* **Are you asking about a specific day or time in the future?** (e.g., "What will the weather be like' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'MAX_TOKENS', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-bc98fdaf-9ed2-47e5-b295-e
# ...

# %%
custom_response=llm.invoke("Explain Quantum Computing in Simple terms ")
print("\nCustom Response",custom_response)
# Out:
# Custom Response content="Okay, let's break down quantum computing in simple terms. Imagine regular computers as light switches: they can be either ON (1) or OFF (0). That's how they store and process information, using bits.\n\nQuantum computers are different. They use **qubits** instead of bits. Think of a qubit as a dimmer switch instead of a light switch. It can be:\n\n*   **ON (1)**\n*   **OFF (0)**\n*   **" additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'MAX_TOKENS', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-90f4d319-ec15-44b8-9c34-bf14622de6ce-0' usage_meta
# ...

# %%
prompt=PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in detail?"
)

# %%
prompt=PromptTemplate(
    input_variables=["location"],
    template="What is the weather like in {location}?"
)

# %%
chain=LLMChain(llm=llm,prompt=prompt)
# Out:
# <ipython-input-48-7f19b7a61494>:1: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain=LLMChain(llm=llm,prompt=prompt)

# %%
chained_response=chain.run("Karachi")
print("\nChain Response",chained_response)
# Out:
# Chain Response The weather in Karachi is generally **hot and humid** for most of the year, with a distinct monsoon season. Here's a breakdown by season:
#
# **Summer (March - May/June):**
#
# * **Very Hot:** Temperatures can soar to 35-40°C (95-104°F) during the day.
# * **High Humidity:** This makes the heat feel even more intense.
# * **Dry:** Rainfall is minimal during this period

# %%
response_data={
    "single-prompt_response":str(response),
    "multiple-prompt_response":str(response),
    "note_response":str(response),
    "conversation":str(memory.load_memory_variables({})),
    "weather_response":str(weather_response),
    "custom_response":str(custom_response),
    "chained_response":str(chained_response)
}

# %%
with open("response_data.json","w") as f:
 json.dump(response_data,f)

# %%
print("\nResponse saved to response_data.json")
# Out:
# Response saved to response_data.json

# %%
with open("response_data.json","r") as f:
 loaded_response_data=json.load(f)
 print("n\Loaded Response",loaded_response_data)
# Out:
# n\Loaded Response {'single-prompt_response': "content='AI is rapidly transforming our world,\\nFrom simple tasks to complex ones unfurled.\\nIts potential is vast, both good and bad,\\nEthical considerations must be had.\\nThe future with AI is yet to be told.\\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-52e2f59b-1e5e-405f-a50e-69a64701d56d-0' usage_metadata={'input_tokens': 7, 'output_tokens': 48, 'total_tokens': 55, 'input_token_details': {'cache_read': 0}}", 'multiple-prompt_response': "content='AI is rap
# ...
