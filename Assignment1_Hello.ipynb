# %% [markdown]
# <a href="https://colab.research.google.com/github/AZ-AZEEZULLAH/python-in-google-colab/blob/main/Assignment1_Hello.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U -q langchain langchain-google-genai


import langchain_google_genai as genai
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.chains import ConversationChain, LLMChain
from langchain.memory import ConversationBufferMemory
from langchain.prompts import PromptTemplate
from langchain.tools import Tool
import json


api_key = "AIzaSyBy7C2FWsiLqWrpCAwqQODgol9ZhnzwK1c"


llm = ChatGoogleGenerativeAI(
    api_key=api_key,
    model="gemini-2.0-flash-exp",
    temperature=0.7,
    max_output_tokens=100
)


response = llm.invoke("Who is the founder of Pakistan?")

print("Single Prompt Response:", response)
response = llm.invoke("When was He Born & Death?")
print(response)
response =llm .invoke("Who is the founder of Turkey")
print(response)

response2 = llm.invoke("Write a short poem about Fox life.")
print("\nPoem Prompt Response:", response2)


memory = ConversationBufferMemory()


conversation = ConversationChain(
    llm=llm,
    memory=memory,
)


print("\nConversation 1:", conversation.run("Who is the founder of Pakistan?"))
print("Conversation 2:", conversation.run("When was he born?"))
print("Conversation 3:", conversation.run("Tell me more about his achievements."))

def get_weather(location):

    return f"The weather in {location} is sunny and warm."

weather_tool = Tool(
    name="WeatherTool",
    func=get_weather,
    description="Provides the current weather for a given location.",
)


weather_response = weather_tool.run("Karachi")
print("\nWeather Tool Response:", weather_response)


custom_response = llm.invoke("Explain quantum computing in simple terms.")
print("\nCustom Prompt Response:", custom_response)


prompt = PromptTemplate(
    input_variables=["topic"],
    template="Explain {topic} in detail.",
)

chain = LLMChain(llm=llm, prompt=prompt)

chained_response = chain.run("machine learning")
print("\nChained Response:", chained_response)


response_data = {
    "single_prompt_response": str(response),
    "poem_prompt_response": str(response2),
    "conversation": str(memory.load_memory_variables({})),
    "weather_response": str(weather_response),
    "custom_response": str(custom_response),
    "chained_response": str(chained_response),
}


with open("response_data.json", "w") as f:
    json.dump(response_data, f)

print("\nResponses saved to response_data.json")



with open("response_data.json", "r") as f:
    loaded_responses = json.load(f)
print("\nLoaded Responses:", loaded_responses)
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 411.6/411.6 kB 12.9 MB/s eta 0:00:00
# Single Prompt Response: content='The founder of Pakistan is **Muhammad Ali Jinnah**. He is also known as Quaid-e-Azam, which means "Great Leader."\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-c0f2ea88-19d8-4323-8172-8bafa1a92fa0-0' usage_metadata={'input_tokens': 8, 'output_tokens': 31, 'total_tokens': 39, 'input_token_details': {'cache_read': 0}}
# content="Please provide me with the name of the person you're asking about. I need a name to tell you their birth and death dates.\n" additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-45b4a437-40e6-44a4-8864-5384c92fb49c-0' usage_metadata={'input_tokens': 8, 'output_tokens': 29, 'total_tokens': 37, 'input_token_details': {'cache_read': 0}}
# content='The founder of the Republic of Turkey is **Mustafa Kemal Atatürk**.\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-89cd1df0-0d36-4a6e-bf5a-7964f3eecedf-0' usage_metadata={'input_tokens': 7, 'output_tokens': 15, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}}
#
# Poem Prompt Response: content='A flash of red, a silent tread,\nThrough tangled woods where shadows spread.\nA pointed nose, a keen bright eye,\nA rustle soft as winds go by.\n\nHe hunts the field, a cunning chase,\nA feathered meal, or furry face.\nHe marks his territory with care,\nA wild heart beating, free as air.\n\nHe sleeps by day in hidden den,\nA secret life, away from men.\nAnd when the moon begins to gle' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'MAX_TOKENS', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-67941bf3-3052-4f77-9d38-9bf90e1a20c9-0' usage_metadata={'input_tokens': 9, 'output_tokens': 100, 'total_tokens': 109, 'input_token_details': {'cache_read': 0}}
# <ipython-input-1-4404b0f80513>:36: LangChainDeprecationWarning: Please see the migration guide at: https://python.langchain.com/docs/versions/migrating_memory/
#   memory = ConversationBufferMemory()
# <ipython-input-1-4404b0f80513>:39: LangChainDeprecationWarning: The class `ConversationChain` was deprecated in LangChain 0.2.7 and will be removed in 1.0. Use :meth:`~RunnableWithMessageHistory: https://python.langchain.com/v0.2/api_reference/core/runnables/langchain_core.runnables.history.RunnableWithMessageHistory.html` instead.
#   conversation = ConversationChain(
# <ipython-input-1-4404b0f80513>:45: LangChainDeprecationWarning: The method `Chain.run` was deprecated in langchain 0.1.0 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   print("\nConversation 1:", conversation.run("Who is the founder of Pakistan?"))
# Conversation 1: Ah, a fascinating question! The founder of Pakistan is a figure of great historical significance: **Muhammad Ali Jinnah**.
#
# Now, it's important to note that "founder" can sometimes be a bit nuanced. While Jinnah is undeniably considered the founder and "Father of the Nation" of Pakistan, the movement for Pakistan involved many other influential figures, and the idea of a separate Muslim state in the Indian subcontinent had roots that predate his leadership. However, Jinnah, through his
# Conversation 2: Excellent question! Muhammad Ali Jinnah was born on **December 25, 1876**. This is a date that is widely celebrated in Pakistan, often with national holidays and commemorations.
#
# It's also worth mentioning that while he was born in Karachi, which is now part of Pakistan, at the time it was part of British India. His birth name was actually Mahomedali Jinnahbhai, and he later adopted the name Muhammad Ali Jinnah. Fascinating
# Conversation 3: Certainly! Muhammad Ali Jinnah's achievements are quite extensive and significantly shaped the course of history in the Indian subcontinent. Here are some of his key accomplishments:
#
# *   **Advocacy for Indian Self-Governance:** Early in his career, Jinnah was a prominent member of the Indian National Congress and advocated for Hindu-Muslim unity and Indian self-governance from the British. He believed in achieving independence through constitutional means. He served as the president of the Indian National Congress in 1
#
# Weather Tool Response: The weather in Karachi is sunny and warm.
#
# Custom Prompt Response: content='Okay, let\'s break down quantum computing in simple terms. Imagine regular computers are like light switches: they can be either ON (1) or OFF (0). That\'s how they store and process information, using bits.\n\nQuantum computers, on the other hand, are like dimmer switches. They\'re not just ON or OFF, but they can be *both* at the same time, or somewhere in between. This "both at the same time" idea is called **super' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'MAX_TOKENS', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-b72cd14e-8bcf-42ea-a7dd-898e7eaa8c49-0' usage_metadata={'input_tokens': 8, 'output_tokens': 100, 'total_tokens': 108, 'input_token_details': {'cache_read': 0}}
# <ipython-input-1-4404b0f80513>:73: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt)
# Chained Response: Okay, let's dive deep into the world of Machine Learning (ML). It's a vast and fascinating field, so we'll break it down into key concepts and ideas.
#
# **What is Machine Learning?**
#
# At its core, Machine Learning is a subset of Artificial Intelligence (AI) that focuses on enabling computers to learn from data without being explicitly programmed. Instead of writing specific rules for every possible scenario, we feed the machine with data, and it identifies patterns, makes predictions
#
# Responses saved to response_data.json
#
# Loaded Responses: {'single_prompt_response': "content='The founder of the Republic of Turkey is **Mustafa Kemal Atatürk**.\\n' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'STOP', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-89cd1df0-0d36-4a6e-bf5a-7964f3eecedf-0' usage_metadata={'input_tokens': 7, 'output_tokens': 15, 'total_tokens': 22, 'input_token_details': {'cache_read': 0}}", 'poem_prompt_response': "content='A flash of red, a silent tread,\\nThrough tangled woods where shadows spread.\\nA pointed nose, a keen bright eye,\\nA rustle soft as winds go by.\\n\\nHe hunts the field, a cunning chase,\\nA feathered meal, or furry face.\\nHe marks his territory with care,\\nA wild heart beating, free as air.\\n\\nHe sleeps by day in hidden den,\\nA secret life, away from men.\\nAnd when the moon begins to gle' additional_kwargs={} response_metadata={'prompt_feedback': {'block_reason': 0, 'safety_ratings': []}, 'finish_reason': 'MAX_TOKENS', 'safety_ratings': [{'category': 'HARM_CATEGORY_HATE_SPEECH', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_DANGEROUS_CONTENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_HARASSMENT', 'probability': 'NEGLIGIBLE', 'blocked': False}, {'category': 'HARM_CATEGORY_SEXUALLY_EXPLICIT', 'probability': 'NEGLIGIBLE', 'blocked': False}]} id='run-67941bf3-3052-4f77-9d38-9bf90e1a20c9-0' usage_metadata={'input_tokens': 9, 'output_tokens': 100, 'total_tokens': 109, 'input_token_details': {'cache_read': 0}}", 'conversation': '{\'history\': \'Human: Who is the founder of Pakistan?\\nAI: Ah, a fascinating question! The founder of Pakistan is a figure of great historical significance: **Muhammad Ali Jinnah**. \\n\\nNow, it\\\'s important to note that "founder" can sometimes be a bit nuanced. While Jinnah is undeniably considered the founder and "Father of the Nation" of Pakistan, the movement for Pakistan involved many other influential figures, and the idea of a separate Muslim state in the Indian subcontinent had roots that predate his leadership. However, Jinnah, through his\\nHuman: When was he born?\\nAI: Excellent question! Muhammad Ali Jinnah was born on **December 25, 1876**. This is a date that is widely celebrated in Pakistan, often with national holidays and commemorations.\\n\\nIt\\\'s also worth mentioning that while he was born in Karachi, which is now part of Pakistan, at the time it was part of British India. His birth name was actually Mahomedali Jinnahbhai, and he later adopted the name Muhammad Ali Jinnah. Fascinating\\nHuman: Tell me more about his achievements.\\nAI: Certainly! Muhammad Ali Jinnah\\\'s achievements are quite extensive and significantly shaped the course of history in the Indian subcontinent. Here are some of his key accomplishments:\\n\\n*   **Advocacy for Indian Self-Governance:** Early in his career, Jinnah was a prominent member of the Indian National Congress and advocated for Hindu-Muslim unity and Indian self-governance from the British. He believed in achieving independence through constitutional means. He served as the president of the Indian National Congress in 1\'}', 'weather_response': 'The weather in Karachi is sunny and warm.', 'custom_response': 'content=\'Okay, let\\\'s break down quantum computing in simple terms. Imagine regular computers are like light switches: they can be either ON (1) or OFF (0). That\\\'s how they store and process information, using bits.\\n\\nQuantum computers, on the other hand, are like dimmer switches. They\\\'re not just ON or OFF, but they can be  ...
